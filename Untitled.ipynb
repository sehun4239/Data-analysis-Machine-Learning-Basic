# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# 이미지를 하나 준비해라
# 이미지가 준비됐으면 불러드리자

img = Image.open('./data/imgs/img.png')

plt.imshow(img)
plt.show()

# pixel data를 ndarray로 뽑아내자
pixel = np.array(img)

print('크기 : {}'.format(img.size))  # image size

# 특정 위치에 pixel값을 알아보자
print('X : {}, Y : {}의 픽셀값은 {}'.format(100,200,pixel[100,200]))
# pixel의 shape을 찍어보자
print(pixel.shape)  # (350, 350, 3)


# image 처리 기본

# 1. 이미지 저장
# img.save('./data/imgs/my_picture.png')

# 2. 이미지 crop
crop_image = img.crop((120,0,240,120))
plt.imshow(crop_image)
plt.show()

# 3. resize
resize_img = img.resize((int(img.size[0]/2), int(img.size[1]/2)))
plt.imshow(resize_img)
plt.show()

# 4. 이미지 회전
rotate_img = img.rotate(180)
plt.imshow(rotate_img)
plt.show()

# 5. 원래 이미지를 흑백 처리
# (R,G,B) 3원색을 RGB의 평균으로 바꾸면 흑백처리된다.
# (10,20,30) => (20,20,20)
grey_pixel = pixel.copy()
for y in range(gre_pixel.shape[0])
# Out:
# 크기 : (350, 350)
# X : 100, Y : 200의 픽셀값은 [154 119  99]
# (350, 350, 3)
