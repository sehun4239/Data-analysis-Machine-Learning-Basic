# %%
### DNN

import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Raw Data Loading
df_train = pd.read_csv('/content/drive/My Drive/MachineLearning/data/fashion/fashion-mnist_train.csv')
df_test = pd.read_csv('/content/drive/My Drive/MachineLearning/data/fashion/fashion-mnist_test.csv')

x_data_train = df_train.drop('label', axis=1, inplace=False)
x_data_test = df_test.drop('label', axis=1, inplace=False)
t_data_train = df_train['label']
t_data_test = df_test['label']

# Min-Max Normalization
scaler = MinMaxScaler()
scaler.fit(x_data_train)
x_data_train_norm = scaler.transform(x_data_train)
x_data_test_norm = scaler.transform(x_data_test)

## Tensorflow##
model = Sequential()

model.add(Dense(256,
                activation='relu',
                kernel_initializer='he_uniform',
                input_shape=(x_data_train_norm.shape[1],)))
model.add(Dropout(0.5))
model.add(Dense(128,
                activation='relu',
                kernel_initializer='he_uniform'))
model.add(Dropout(0.5))
model.add(Dense(10,
                activation='softmax',
                kernel_initializer='he_uniform'))

print(model.summary())

model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

history = model.fit(x_data_train_norm,
                    t_data_train,
                    epochs=100,
                    batch_size=100,
                    verbose=1,
                    validation_split=0.3)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 235,146
# Trainable params: 235,146
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.8317 - sparse_categorical_accuracy: 0.7076 - val_loss: 0.4884 - val_sparse_categorical_accuracy: 0.8231
# Epoch 2/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.5508 - sparse_categorical_accuracy: 0.8016 - val_loss: 0.4387 - val_sparse_categorical_accuracy: 0.8419
# Epoch 3/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.5032 - sparse_categorical_accuracy: 0.8197 - val_loss: 0.4024 - val_sparse_categorical_accuracy: 0.8559
# Epoch 4/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.4651 - sparse_categorical_accuracy: 0.8323 - val_loss: 0.3870 - val_sparse_categorical_accuracy: 0.8615
# Epoch 5/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.4480 - sparse_categorical_accuracy: 0.8372 - val_loss: 0.3904 - val_sparse_categorical_accuracy: 0.8601
# Epoch 6/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.4307 - sparse_categorical_accuracy: 0.8447 - val_loss: 0.3687 - val_sparse_categorical_accuracy: 0.8684
# Epoch 7/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.4277 - sparse_categorical_accuracy: 0.8460 - val_loss: 0.3774 - val_sparse_categorical_accuracy: 0.8670
# Epoch 8/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.4115 - sparse_categorical_accuracy: 0.8500 - val_loss: 0.3698 - val_sparse_categorical_accuracy: 0.8656
# Epoch 9/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.4015 - sparse_categorical_accuracy: 0.8549 - val_loss: 0.3586 - val_sparse_categorical_accuracy: 0.8716
# Epoch 10/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3942 - sparse_categorical_accuracy: 0.8564 - val_loss: 0.3660 - val_sparse_categorical_accuracy: 0.8716
# Epoch 11/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3873 - sparse_categorical_accuracy: 0.8570 - val_loss: 0.3565 - val_sparse_categorical_accuracy: 0.8736
# Epoch 12/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3771 - sparse_categorical_accuracy: 0.8628 - val_loss: 0.3499 - val_sparse_categorical_accuracy: 0.8743
# Epoch 13/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3694 - sparse_categorical_accuracy: 0.8653 - val_loss: 0.3546 - val_sparse_categorical_accuracy: 0.8739
# Epoch 14/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3690 - sparse_categorical_accuracy: 0.8650 - val_loss: 0.3487 - val_sparse_categorical_accuracy: 0.8734
# Epoch 15/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3641 - sparse_categorical_accuracy: 0.8678 - val_loss: 0.3421 - val_sparse_categorical_accuracy: 0.8721
# Epoch 16/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3583 - sparse_categorical_accuracy: 0.8695 - val_loss: 0.3399 - val_sparse_categorical_accuracy: 0.8761
# Epoch 17/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3534 - sparse_categorical_accuracy: 0.8718 - val_loss: 0.3369 - val_sparse_categorical_accuracy: 0.8759
# Epoch 18/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3549 - sparse_categorical_accuracy: 0.8706 - val_loss: 0.3338 - val_sparse_categorical_accuracy: 0.8779
# Epoch 19/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3481 - sparse_categorical_accuracy: 0.8729 - val_loss: 0.3317 - val_sparse_categorical_accuracy: 0.8799
# Epoch 20/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3428 - sparse_categorical_accuracy: 0.8739 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8822
# Epoch 21/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3406 - sparse_categorical_accuracy: 0.8744 - val_loss: 0.3413 - val_sparse_categorical_accuracy: 0.8771
# Epoch 22/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3333 - sparse_categorical_accuracy: 0.8762 - val_loss: 0.3292 - val_sparse_categorical_accuracy: 0.8841
# Epoch 23/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3321 - sparse_categorical_accuracy: 0.8790 - val_loss: 0.3276 - val_sparse_categorical_accuracy: 0.8829
# Epoch 24/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3295 - sparse_categorical_accuracy: 0.8781 - val_loss: 0.3277 - val_sparse_categorical_accuracy: 0.8864
# Epoch 25/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3282 - sparse_categorical_accuracy: 0.8796 - val_loss: 0.3287 - val_sparse_categorical_accuracy: 0.8824
# Epoch 26/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3284 - sparse_categorical_accuracy: 0.8803 - val_loss: 0.3286 - val_sparse_categorical_accuracy: 0.8822
# Epoch 27/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3230 - sparse_categorical_accuracy: 0.8796 - val_loss: 0.3274 - val_sparse_categorical_accuracy: 0.8852
# Epoch 28/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3217 - sparse_categorical_accuracy: 0.8831 - val_loss: 0.3230 - val_sparse_categorical_accuracy: 0.8866
# Epoch 29/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3152 - sparse_categorical_accuracy: 0.8840 - val_loss: 0.3279 - val_sparse_categorical_accuracy: 0.8856
# Epoch 30/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3174 - sparse_categorical_accuracy: 0.8830 - val_loss: 0.3268 - val_sparse_categorical_accuracy: 0.8855
# Epoch 31/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3143 - sparse_categorical_accuracy: 0.8841 - val_loss: 0.3236 - val_sparse_categorical_accuracy: 0.8842
# Epoch 32/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3098 - sparse_categorical_accuracy: 0.8852 - val_loss: 0.3238 - val_sparse_categorical_accuracy: 0.8861
# Epoch 33/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3057 - sparse_categorical_accuracy: 0.8860 - val_loss: 0.3255 - val_sparse_categorical_accuracy: 0.8852
# Epoch 34/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3055 - sparse_categorical_accuracy: 0.8873 - val_loss: 0.3306 - val_sparse_categorical_accuracy: 0.8868
# Epoch 35/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3040 - sparse_categorical_accuracy: 0.8855 - val_loss: 0.3237 - val_sparse_categorical_accuracy: 0.8881
# Epoch 36/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3036 - sparse_categorical_accuracy: 0.8880 - val_loss: 0.3321 - val_sparse_categorical_accuracy: 0.8829
# Epoch 37/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.3043 - sparse_categorical_accuracy: 0.8865 - val_loss: 0.3196 - val_sparse_categorical_accuracy: 0.8881
# Epoch 38/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2973 - sparse_categorical_accuracy: 0.8877 - val_loss: 0.3239 - val_sparse_categorical_accuracy: 0.8838
# Epoch 39/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2960 - sparse_categorical_accuracy: 0.8908 - val_loss: 0.3240 - val_sparse_categorical_accuracy: 0.8869
# Epoch 40/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2980 - sparse_categorical_accuracy: 0.8899 - val_loss: 0.3297 - val_sparse_categorical_accuracy: 0.8829
# Epoch 41/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2960 - sparse_categorical_accuracy: 0.8883 - val_loss: 0.3274 - val_sparse_categorical_accuracy: 0.8867
# Epoch 42/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2942 - sparse_categorical_accuracy: 0.8901 - val_loss: 0.3250 - val_sparse_categorical_accuracy: 0.8864
# Epoch 43/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2891 - sparse_categorical_accuracy: 0.8923 - val_loss: 0.3234 - val_sparse_categorical_accuracy: 0.8892
# Epoch 44/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2923 - sparse_categorical_accuracy: 0.8903 - val_loss: 0.3214 - val_sparse_categorical_accuracy: 0.8886
# Epoch 45/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2890 - sparse_categorical_accuracy: 0.8932 - val_loss: 0.3227 - val_sparse_categorical_accuracy: 0.8874
# Epoch 46/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2868 - sparse_categorical_accuracy: 0.8939 - val_loss: 0.3254 - val_sparse_categorical_accuracy: 0.8879
# Epoch 47/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2843 - sparse_categorical_accuracy: 0.8950 - val_loss: 0.3255 - val_sparse_categorical_accuracy: 0.8862
# Epoch 48/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2816 - sparse_categorical_accuracy: 0.8970 - val_loss: 0.3267 - val_sparse_categorical_accuracy: 0.8862
# Epoch 49/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2815 - sparse_categorical_accuracy: 0.8955 - val_loss: 0.3272 - val_sparse_categorical_accuracy: 0.8858
# Epoch 50/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2772 - sparse_categorical_accuracy: 0.8957 - val_loss: 0.3275 - val_sparse_categorical_accuracy: 0.8827
# Epoch 51/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2830 - sparse_categorical_accuracy: 0.8941 - val_loss: 0.3195 - val_sparse_categorical_accuracy: 0.8874
# Epoch 52/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2781 - sparse_categorical_accuracy: 0.8947 - val_loss: 0.3374 - val_sparse_categorical_accuracy: 0.8806
# Epoch 53/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2780 - sparse_categorical_accuracy: 0.8958 - val_loss: 0.3348 - val_sparse_categorical_accuracy: 0.8852
# Epoch 54/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2771 - sparse_categorical_accuracy: 0.8961 - val_loss: 0.3287 - val_sparse_categorical_accuracy: 0.8883
# Epoch 55/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2776 - sparse_categorical_accuracy: 0.8967 - val_loss: 0.3200 - val_sparse_categorical_accuracy: 0.8916
# Epoch 56/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2781 - sparse_categorical_accuracy: 0.8970 - val_loss: 0.3223 - val_sparse_categorical_accuracy: 0.8898
# Epoch 57/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2769 - sparse_categorical_accuracy: 0.8976 - val_loss: 0.3323 - val_sparse_categorical_accuracy: 0.8873
# Epoch 58/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2778 - sparse_categorical_accuracy: 0.8971 - val_loss: 0.3252 - val_sparse_categorical_accuracy: 0.8892
# Epoch 59/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2716 - sparse_categorical_accuracy: 0.8975 - val_loss: 0.3251 - val_sparse_categorical_accuracy: 0.8889
# Epoch 60/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2709 - sparse_categorical_accuracy: 0.8984 - val_loss: 0.3275 - val_sparse_categorical_accuracy: 0.8897
# Epoch 61/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2701 - sparse_categorical_accuracy: 0.8988 - val_loss: 0.3397 - val_sparse_categorical_accuracy: 0.8854
# Epoch 62/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2676 - sparse_categorical_accuracy: 0.9008 - val_loss: 0.3296 - val_sparse_categorical_accuracy: 0.8911
# Epoch 63/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2657 - sparse_categorical_accuracy: 0.9016 - val_loss: 0.3403 - val_sparse_categorical_accuracy: 0.8878
# Epoch 64/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2687 - sparse_categorical_accuracy: 0.8985 - val_loss: 0.3311 - val_sparse_categorical_accuracy: 0.8910
# Epoch 65/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2669 - sparse_categorical_accuracy: 0.8995 - val_loss: 0.3246 - val_sparse_categorical_accuracy: 0.8899
# Epoch 66/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2618 - sparse_categorical_accuracy: 0.9028 - val_loss: 0.3219 - val_sparse_categorical_accuracy: 0.8909
# Epoch 67/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2635 - sparse_categorical_accuracy: 0.9009 - val_loss: 0.3296 - val_sparse_categorical_accuracy: 0.8904
# Epoch 68/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2609 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.3262 - val_sparse_categorical_accuracy: 0.8898
# Epoch 69/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2596 - sparse_categorical_accuracy: 0.9026 - val_loss: 0.3309 - val_sparse_categorical_accuracy: 0.8900
# Epoch 70/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2602 - sparse_categorical_accuracy: 0.9036 - val_loss: 0.3295 - val_sparse_categorical_accuracy: 0.8898
# Epoch 71/100
# 420/420 [==============================] - 1s 4ms/step - loss: 0.2635 - sparse_categorical_accuracy: 0.9031 - val_loss: 0.3303 - val_sparse_categorical_accuracy: 0.8866
# Epoch 72/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2619 - sparse_categorical_accuracy: 0.9023 - val_loss: 0.3241 - val_sparse_categorical_accuracy: 0.8914
# Epoch 73/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2596 - sparse_categorical_accuracy: 0.9034 - val_loss: 0.3278 - val_sparse_categorical_accuracy: 0.8907
# Epoch 74/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2594 - sparse_categorical_accuracy: 0.9046 - val_loss: 0.3226 - val_sparse_categorical_accuracy: 0.8909
# Epoch 75/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2562 - sparse_categorical_accuracy: 0.9050 - val_loss: 0.3260 - val_sparse_categorical_accuracy: 0.8860
# Epoch 76/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2541 - sparse_categorical_accuracy: 0.9057 - val_loss: 0.3459 - val_sparse_categorical_accuracy: 0.8884
# Epoch 77/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2587 - sparse_categorical_accuracy: 0.9047 - val_loss: 0.3268 - val_sparse_categorical_accuracy: 0.8908
# Epoch 78/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2510 - sparse_categorical_accuracy: 0.9071 - val_loss: 0.3275 - val_sparse_categorical_accuracy: 0.8916
# Epoch 79/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2532 - sparse_categorical_accuracy: 0.9045 - val_loss: 0.3313 - val_sparse_categorical_accuracy: 0.8930
# Epoch 80/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2493 - sparse_categorical_accuracy: 0.9077 - val_loss: 0.3248 - val_sparse_categorical_accuracy: 0.8918
# Epoch 81/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2495 - sparse_categorical_accuracy: 0.9065 - val_loss: 0.3314 - val_sparse_categorical_accuracy: 0.8911
# Epoch 82/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2527 - sparse_categorical_accuracy: 0.9077 - val_loss: 0.3415 - val_sparse_categorical_accuracy: 0.8883
# Epoch 83/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2530 - sparse_categorical_accuracy: 0.9057 - val_loss: 0.3253 - val_sparse_categorical_accuracy: 0.8914
# Epoch 84/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2516 - sparse_categorical_accuracy: 0.9050 - val_loss: 0.3326 - val_sparse_categorical_accuracy: 0.8893
# Epoch 85/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2475 - sparse_categorical_accuracy: 0.9074 - val_loss: 0.3272 - val_sparse_categorical_accuracy: 0.8908
# Epoch 86/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2475 - sparse_categorical_accuracy: 0.9083 - val_loss: 0.3430 - val_sparse_categorical_accuracy: 0.8918
# Epoch 87/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2440 - sparse_categorical_accuracy: 0.9076 - val_loss: 0.3308 - val_sparse_categorical_accuracy: 0.8908
# Epoch 88/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2517 - sparse_categorical_accuracy: 0.9065 - val_loss: 0.3360 - val_sparse_categorical_accuracy: 0.8909
# Epoch 89/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2478 - sparse_categorical_accuracy: 0.9084 - val_loss: 0.3392 - val_sparse_categorical_accuracy: 0.8921
# Epoch 90/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2455 - sparse_categorical_accuracy: 0.9080 - val_loss: 0.3291 - val_sparse_categorical_accuracy: 0.8937
# Epoch 91/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2463 - sparse_categorical_accuracy: 0.9070 - val_loss: 0.3361 - val_sparse_categorical_accuracy: 0.8920
# Epoch 92/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2441 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.3305 - val_sparse_categorical_accuracy: 0.8929
# Epoch 93/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2430 - sparse_categorical_accuracy: 0.9095 - val_loss: 0.3328 - val_sparse_categorical_accuracy: 0.8907
# Epoch 94/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2419 - sparse_categorical_accuracy: 0.9097 - val_loss: 0.3327 - val_sparse_categorical_accuracy: 0.8897
# Epoch 95/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2393 - sparse_categorical_accuracy: 0.9107 - val_loss: 0.3467 - val_sparse_categorical_accuracy: 0.8901
# Epoch 96/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2391 - sparse_categorical_accuracy: 0.9118 - val_loss: 0.3335 - val_sparse_categorical_accuracy: 0.8908
# Epoch 97/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2374 - sparse_categorical_accuracy: 0.9103 - val_loss: 0.3436 - val_sparse_categorical_accuracy: 0.8898
# Epoch 98/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2416 - sparse_categorical_accuracy: 0.9096 - val_loss: 0.3325 - val_sparse_categorical_accuracy: 0.8942
# Epoch 99/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2370 - sparse_categorical_accuracy: 0.9117 - val_loss: 0.3420 - val_sparse_categorical_accuracy: 0.8903
# Epoch 100/100
# 420/420 [==============================] - 1s 3ms/step - loss: 0.2354 - sparse_categorical_accuracy: 0.9119 - val_loss: 0.3383 - val_sparse_categorical_accuracy: 0.8917

# %%
model.evaluate(x_data_test_norm,
                t_data_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3276 - sparse_categorical_accuracy: 0.8931
# [0.32763975858688354, 0.8931000232696533]

# %%
###### CNN
# %reset

import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.layers import Dropout, Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# Raw Data Loading
df_train = pd.read_csv('/content/drive/My Drive/MachineLearning/data/fashion/fashion-mnist_train.csv')
df_test = pd.read_csv('/content/drive/My Drive/MachineLearning/data/fashion/fashion-mnist_test.csv')

# Data Split(Train data와 Test data 분리)
x_data_train = df_train.drop('label', axis=1, inplace=False)
x_data_test = df_test.drop('label', axis=1, inplace=False)
t_data_train = df_train['label']
t_data_test = df_test['label']

# Min-Max Normalization
scaler = MinMaxScaler()
scaler.fit(x_data_train)
x_data_train_norm = scaler.transform(x_data_train)
x_data_test_norm = scaler.transform(x_data_test)

## Tensorflow ##

model = Sequential()
model.add(Conv2D(64, kernel_size=(3, 3),
                 activation='relu',
                 kernel_initializer='he_normal',
                 padding='same',
                 input_shape=(28, 28, 1)))
model.add(Conv2D(64, 
                 kernel_size=(3, 3), 
                 activation='relu',padding='same'))
model.add(tf.keras.layers.BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(128, kernel_size=(3, 3),
                 activation='relu',
                 kernel_initializer='he_normal',
                 padding='same'))
model.add(Conv2D(128, kernel_size=(3, 3), 
                 padding='same',
                 activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Conv2D(256, kernel_size=(3, 3),
                 activation='relu',
                 kernel_initializer='he_normal',
                 padding='same'))
model.add(Conv2D(256, 
                 kernel_size=(3, 3), 
                 padding='same',
                 activation='relu'))
model.add(Conv2D(256, 
                 kernel_size=(3, 3), 
                 padding='same',
                 activation='relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(2048, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()

model.compile(optimizer=Adam(learning_rate=1e-3),
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

history = model.fit(x_data_train_norm.reshape(-1, 28, 28, 1),
                    t_data_train,
                    epochs=50,
                    batch_size=50,
                    verbose=1,
                    validation_split=0.3)
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 28, 28, 64)        640
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 14, 14, 128)       73856
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 14, 14, 128)       147584
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 7, 7, 256)         295168
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 7, 7, 256)         590080
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 7, 7, 256)         590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# max_pooling2d_23 (MaxPooling (None, 3, 3, 256)         0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 3, 3, 256)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2304)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 2048)              4720640
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 2048)              0
# _________________________________________________________________
# dense_20 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# dense_21 (Dense)             (None, 10)                5130
# =================================================================
# Total params: 7,510,986
# Trainable params: 7,510,090
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/50
# 840/840 [==============================] - ETA: 0s - loss: 0.6009 - sparse_categorical_accuracy: 0.7865WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0013s vs `on_test_batch_end` time: 0.0028s). Check your callbacks.
# 840/840 [==============================] - 14s 16ms/step - loss: 0.6009 - sparse_categorical_accuracy: 0.7865 - val_loss: 0.4545 - val_sparse_categorical_accuracy: 0.8452
# Epoch 2/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.3568 - sparse_categorical_accuracy: 0.8687 - val_loss: 0.3531 - val_sparse_categorical_accuracy: 0.8728
# Epoch 3/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.3074 - sparse_categorical_accuracy: 0.8865 - val_loss: 0.3236 - val_sparse_categorical_accuracy: 0.8858
# Epoch 4/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.2790 - sparse_categorical_accuracy: 0.8972 - val_loss: 0.2679 - val_sparse_categorical_accuracy: 0.9037
# Epoch 5/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.2582 - sparse_categorical_accuracy: 0.9068 - val_loss: 0.2870 - val_sparse_categorical_accuracy: 0.8946
# Epoch 6/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.2417 - sparse_categorical_accuracy: 0.9125 - val_loss: 0.2472 - val_sparse_categorical_accuracy: 0.9101
# Epoch 7/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.2207 - sparse_categorical_accuracy: 0.9198 - val_loss: 0.2282 - val_sparse_categorical_accuracy: 0.9191
# Epoch 8/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.2139 - sparse_categorical_accuracy: 0.9230 - val_loss: 0.2196 - val_sparse_categorical_accuracy: 0.9219
# Epoch 9/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.2021 - sparse_categorical_accuracy: 0.9270 - val_loss: 0.2116 - val_sparse_categorical_accuracy: 0.9277
# Epoch 10/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1848 - sparse_categorical_accuracy: 0.9323 - val_loss: 0.2123 - val_sparse_categorical_accuracy: 0.9262
# Epoch 11/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1787 - sparse_categorical_accuracy: 0.9352 - val_loss: 0.2097 - val_sparse_categorical_accuracy: 0.9267
# Epoch 12/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1698 - sparse_categorical_accuracy: 0.9391 - val_loss: 0.2081 - val_sparse_categorical_accuracy: 0.9317
# Epoch 13/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1561 - sparse_categorical_accuracy: 0.9427 - val_loss: 0.2059 - val_sparse_categorical_accuracy: 0.9307
# Epoch 14/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1528 - sparse_categorical_accuracy: 0.9443 - val_loss: 0.2371 - val_sparse_categorical_accuracy: 0.9234
# Epoch 15/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1598 - sparse_categorical_accuracy: 0.9427 - val_loss: 0.2019 - val_sparse_categorical_accuracy: 0.9342
# Epoch 16/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1313 - sparse_categorical_accuracy: 0.9507 - val_loss: 0.2143 - val_sparse_categorical_accuracy: 0.9321
# Epoch 17/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.1264 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.2121 - val_sparse_categorical_accuracy: 0.9319
# Epoch 18/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1217 - sparse_categorical_accuracy: 0.9549 - val_loss: 0.2126 - val_sparse_categorical_accuracy: 0.9343
# Epoch 19/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1182 - sparse_categorical_accuracy: 0.9566 - val_loss: 0.2218 - val_sparse_categorical_accuracy: 0.9323
# Epoch 20/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1304 - sparse_categorical_accuracy: 0.9542 - val_loss: 0.2214 - val_sparse_categorical_accuracy: 0.9343
# Epoch 21/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1115 - sparse_categorical_accuracy: 0.9598 - val_loss: 0.2230 - val_sparse_categorical_accuracy: 0.9324
# Epoch 22/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1050 - sparse_categorical_accuracy: 0.9617 - val_loss: 0.2351 - val_sparse_categorical_accuracy: 0.9348
# Epoch 23/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.1018 - sparse_categorical_accuracy: 0.9624 - val_loss: 0.2174 - val_sparse_categorical_accuracy: 0.9378
# Epoch 24/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0873 - sparse_categorical_accuracy: 0.9679 - val_loss: 0.2199 - val_sparse_categorical_accuracy: 0.9365
# Epoch 25/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0878 - sparse_categorical_accuracy: 0.9689 - val_loss: 0.2545 - val_sparse_categorical_accuracy: 0.9380
# Epoch 26/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0892 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.2434 - val_sparse_categorical_accuracy: 0.9346
# Epoch 27/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0825 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.2440 - val_sparse_categorical_accuracy: 0.9347
# Epoch 28/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0799 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.2503 - val_sparse_categorical_accuracy: 0.9303
# Epoch 29/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0837 - sparse_categorical_accuracy: 0.9702 - val_loss: 0.2613 - val_sparse_categorical_accuracy: 0.9355
# Epoch 30/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0809 - sparse_categorical_accuracy: 0.9720 - val_loss: 0.2606 - val_sparse_categorical_accuracy: 0.9340
# Epoch 31/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0687 - sparse_categorical_accuracy: 0.9755 - val_loss: 0.2750 - val_sparse_categorical_accuracy: 0.9354
# Epoch 32/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0812 - sparse_categorical_accuracy: 0.9724 - val_loss: 0.2674 - val_sparse_categorical_accuracy: 0.9348
# Epoch 33/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.0633 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.2515 - val_sparse_categorical_accuracy: 0.9363
# Epoch 34/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.0576 - sparse_categorical_accuracy: 0.9794 - val_loss: 0.3014 - val_sparse_categorical_accuracy: 0.9322
# Epoch 35/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0600 - sparse_categorical_accuracy: 0.9798 - val_loss: 0.2661 - val_sparse_categorical_accuracy: 0.9368
# Epoch 36/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.0583 - sparse_categorical_accuracy: 0.9790 - val_loss: 0.2867 - val_sparse_categorical_accuracy: 0.9309
# Epoch 37/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.0592 - sparse_categorical_accuracy: 0.9798 - val_loss: 0.2970 - val_sparse_categorical_accuracy: 0.9349
# Epoch 38/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0731 - sparse_categorical_accuracy: 0.9773 - val_loss: 0.2941 - val_sparse_categorical_accuracy: 0.9362
# Epoch 39/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.0542 - sparse_categorical_accuracy: 0.9813 - val_loss: 0.2750 - val_sparse_categorical_accuracy: 0.9350
# Epoch 40/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.0533 - sparse_categorical_accuracy: 0.9815 - val_loss: 0.2532 - val_sparse_categorical_accuracy: 0.9375
# Epoch 41/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.0667 - sparse_categorical_accuracy: 0.9797 - val_loss: 0.3271 - val_sparse_categorical_accuracy: 0.9360
# Epoch 42/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0500 - sparse_categorical_accuracy: 0.9829 - val_loss: 0.2938 - val_sparse_categorical_accuracy: 0.9357
# Epoch 43/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0641 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.3213 - val_sparse_categorical_accuracy: 0.9351
# Epoch 44/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.0527 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.2689 - val_sparse_categorical_accuracy: 0.9340
# Epoch 45/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0642 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.2977 - val_sparse_categorical_accuracy: 0.9334
# Epoch 46/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9846 - val_loss: 0.3000 - val_sparse_categorical_accuracy: 0.9410
# Epoch 47/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0421 - sparse_categorical_accuracy: 0.9853 - val_loss: 0.3129 - val_sparse_categorical_accuracy: 0.9377
# Epoch 48/50
# 840/840 [==============================] - 14s 16ms/step - loss: 0.0414 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.2984 - val_sparse_categorical_accuracy: 0.9358
# Epoch 49/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.0399 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.3295 - val_sparse_categorical_accuracy: 0.9338
# Epoch 50/50
# 840/840 [==============================] - 14s 17ms/step - loss: 0.0404 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.3330 - val_sparse_categorical_accuracy: 0.9389

# %%
model.evaluate(x_data_test_norm.reshape(-1,28,28,1),
                t_data_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.3059 - sparse_categorical_accuracy: 0.9415
# [0.30593162775039673, 0.9415000081062317]
